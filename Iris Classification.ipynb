# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
Df = pd.read_csv('Iris.csv')
Df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Df.drop(columns = 'Id', inplace = True)
Df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Df.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
Df.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
Df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
Df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
Df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
Df['SepalLengthCm'].hist()
# Out:
# <Axes: >

# %%
Df['SepalWidthCm'].hist()
# Out:
# <Axes: >

# %%
Df['PetalLengthCm'].hist()
# Out:
# <Axes: >

# %%
Df['PetalWidthCm'].hist()
# Out:
# <Axes: >

# %%
sns.FacetGrid(Df, hue="Species",height=6).map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend()

# %%
sns.FacetGrid(Df, hue="Species",height=6).map(plt.scatter,"PetalLengthCm","PetalWidthCm").add_legend()

# %%
sns.FacetGrid(Df, hue="Species",height=6).map(plt.scatter,"SepalLengthCm","PetalWidthCm").add_legend()

# %%
sns.FacetGrid(Df, hue="Species",height=6).map(plt.scatter,"PetalLengthCm","SepalWidthCm").add_legend()

# %%
sns.pairplot(Df)
plt.show()

# %%
corr = Df.corr(numeric_only=True,method="spearman")
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
sns.heatmap(corr)
plt.show()

# %%
Df.corr(numeric_only = True,method = "spearman")
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.159457       0.881386      0.834421
# SepalWidthCm       -0.159457      1.000000      -0.303421     -0.277511
# PetalLengthCm       0.881386     -0.303421       1.000000      0.936003
# PetalWidthCm        0.834421     -0.277511       0.936003      1.000000

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
Df['Species'] = le.fit_transform(Df['Species'])
Df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
Df['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
Df.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2

# %%
from sklearn.model_selection import train_test_split
X = Df.drop(columns = 'Species')
Y = Df['Species']
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.30)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print("Accuracy :", model.score(x_test,y_test))
# Out:
# Accuracy : 0.9111111111111111

# %%
model.predict([[2,3,2.2,2.8]])
# Out:
# C:\Users\vedra\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
